# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time
from time import sleep
from selenium.webdriver import ActionChains
#from selenium.common.exceptions import NoSuchElementException

# %%
# driver connection
driver=webdriver.Chrome(r"D:\Software\chromedriver_win32\chromedriver.exe")

# %%
#Q-1 and 2
driver.get("https://www.amazon.in/")

# %%
prod_name=driver.find_element(By.CLASS_NAME,"nav-input")
prod_name.send_keys('guitar')
search=driver.find_element(By.ID,"nav-search-submit-button")
search.click()

# %%
brand_name=[]
product_name=[]
product_price=[]
product_exchange_return=[]
product_delivery=[]
product_availability=[]
product_url=[]

start=0
end=3
for page in range(0,3):
    try:
        brand=driver.find_elements(By.XPATH,"//span[@class='a-size-base-plus a-color-base a-text-normal']")
        for i in brand:
            brand_name.append(i.text)
            #print(i.text)
    except NoSuchElementException:
        brand_name.append('--') 
    
    try:
        price=driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
        for i in price:
            product_price.append(i.text)
            print(i.text)
    except NoSuchElementException:
        brand_name.append('--')
        
    try:
        delivery=driver.find_elements(By.XPATH,"//span[@class='a-color-base a-text-bold']")
        for i in delivery:
            product_delivery.append(i.text)
            print(i.text)
    except NoSuchElementException:
        product_delivery.append('--')
        
    try:
        url=driver.find_elements(By.CLASS_NAME,"s-image")
        for i in url:
            product_url.append(i.get_attribute('src'))
            #print(i.get_attribute('src'))
    except NoSuchElementException:
        product_url.append('--')
        
    try:
        availabile=driver.find_elements(By.XPATH,"//span[@class='a-size-base a-color-price']")
        for i in availabile:
            product_availability.append(i.text)
            #print(i.text)
    except NoSuchElementException:
        product_availability.append('--')
        
    next_button=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[67]/div/div/span/a[3]")
    next_button.click()
    
        
    print("NEXT BUTTON CLICKED")
    
    print("__________________________________________")
    print("Brand name---",len(brand_name))
    print("price---",len(product_price))
    print("Delivery---",len(product_delivery))
    print("Image URL---",len(product_url))
    print("Available---",len(product_availability))
    #By.CLASS_NAME,"s-pagination-next"
# Out:
# 2,802
# 3,399
# 3,998
# 6,399
# 7,449
# 2,386
# 1,773
# 1,797
# 1,697
# 7,449
# 12,789
# 9,488
# 4,480
#
# 1,988
# 2,505
# 2,505
# 2,539
# 1,989
# 2,117
# 2,188
# 1,898
# 1,797
# 1,698
# 2,268
# 1,989
# 2,142
# 1,499
# 999
# 2,605
# 965
# 4,999
# 4,750
# 5,299
# 4,480
# 1,698
# 2,269
# 1,871
# 2,802
# 7,489
# 5,299
# 3,499
# 2,198
# 2,188
# 7,490
# 2,198
# 4,436
# 8,999
# 1,999
# 3,998
# 2,699
# 2,450
# 7,727
# 2,386
# 2,188
# 2,437
# 2,578
# 4,270
# 2,999
# 9,488
# 7,282
# 2,190
# 13,990
# 925
# 4,270
# 999
# 6,499
# Sunday, September 25
# Monday, September 26
# tomorrow, September 23
# Monday, September 26
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# tomorrow, September 23
# ...

# %%
#Q-3
# driver connection
driver2=webdriver.Chrome(r"D:\Software\chromedriver_win32\chromedriver.exe")
driver2.get("https://images.google.com/")

# %%
keyword_name=driver2.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input")

# %%
#cars

keyword_name.send_keys('cars')
search_keyword=driver2.find_element(By.CLASS_NAME,"zgAlFc")
search_keyword.click()
keyword_url=[]
url2=driver2.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in url2[0:10]:
    keyword_url.append(i.get_attribute('src'))
    #print(i.get_attribute('src'))
print(len(keyword_url))
# Out:
# 10

# %%
#fruits

keyword_name.send_keys('fruits')
search_keyword=driver2.find_element(By.CLASS_NAME,"zgAlFc")
search_keyword.click()
keyword_url=[]
url2=driver2.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in url2[0:10]:
    keyword_url.append(i.get_attribute('src'))
    #print(i.get_attribute('src'))
print(len(keyword_url))
# Out:
# 10

# %%
#Machine Learning

keyword_name.send_keys('Machine Learning')
search_keyword=driver2.find_element(By.CLASS_NAME,"zgAlFc")
search_keyword.click()
keyword_url=[]
url2=driver2.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in url2[0:10]:
    keyword_url.append(i.get_attribute('src'))
    #print(i.get_attribute('src'))
print(len(keyword_url))
# Out:
# 10

# %%
#Guitar

keyword_name.send_keys('Guitar')
search_keyword=driver2.find_element(By.CLASS_NAME,"zgAlFc")
search_keyword.click()
keyword_url=[]
url2=driver2.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in url2[0:10]:
    keyword_url.append(i.get_attribute('src'))
    #print(i.get_attribute('src'))
print(len(keyword_url))
# Out:
# 10

# %%
#Cakes

keyword_name.send_keys('Cakes')
search_keyword=driver2.find_element(By.CLASS_NAME,"zgAlFc")
search_keyword.click()
keyword_url=[]
url2=driver2.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in url2[0:10]:
    keyword_url.append(i.get_attribute('src'))
    #print(i.get_attribute('src'))
print(len(keyword_url))
# Out:
# 10

# %%
#Q-4
driver3=webdriver.Chrome(r"D:\Software\chromedriver_win32\chromedriver.exe")
driver3.get("https://www.flipkart.com/")

# %%
search_item=driver3.find_element(By.CLASS_NAME,"_3704LK")
search_item.send_keys('samsung mobiles')
search_flip=driver3.find_element(By.CLASS_NAME,"L0Z3Pu")
search_flip.click()

# %%
brand_name=[]
smartphone_name=[]
color=[]
phone_ram=[]
phone_storage=[]
display_size=[]
primary_camara=[]
secondary_camara=[]
battery_capacity=[]
phone_price=[]
phone_link=[]

brand_phone=driver3.find_elements(By.CLASS_NAME,"_4rR01T")
for i in brand_phone:
    test=i.text
    test1=test.split(" ")   
    brand_name.append(test1[0])    
    #pp=test.split(' ', 1)
    smartphone_name.append(test.split(' ', 1)[1])    

ram=driver3.find_elements(By.XPATH,'//li[@class="rgWa7D"][1]')
for i in ram:
    j=i.text
    #print(j)
    jj=j.split("|")
    #print(jj[0])
    phone_ram.append(jj[0])

ram=driver3.find_elements(By.XPATH,'//li[@class="rgWa7D"][1]')
for i in ram:
    try:
        j=i.text
        #print(j)
        jj=j.split("|")    
        #print(jj[1])
        phone_storage.append(jj[1])
    except IndexError:
        #print("error")
        phone_storage.append("--")

display=driver3.find_elements(By.XPATH,'//li[@class="rgWa7D"][2]')
for i in display:
    try:
        j=i.text
        #print(j) 
        display_size.append(j)
    except IndexError:
        #print("error")
        display_size.append("--")
        
camara=driver3.find_elements(By.XPATH,'//li[@class="rgWa7D"][3]')
for i in camara:
    try:
        j=i.text
        #print(j)
        jj=j.split("|")
        primary_camara.append(jj[0])
    except IndexError:
        #print("error")
        primary_camara.append("--")

camara=driver3.find_elements(By.XPATH,'//li[@class="rgWa7D"][3]')
for i in camara:
    try:
        j=i.text
        #print(j)
        jj=j.split("|")
        secondary_camara.append(jj[1])
    except IndexError:
        #print("error")
        secondary_camara.append("--")
        
battery=driver3.find_elements(By.XPATH,'//li[@class="rgWa7D"][4]')
for i in battery:
    try:
        j=i.text
        #print(j)
        jj=j.split(" ")
        battery_capacity.append(jj[0])
    except IndexError:
        #print("error")
        battery_capacity.append("--")
        
price=driver3.find_elements(By.XPATH,'//div[@class="_30jeq3 _1_WHN1"]')
for i in price:
    #print(i.text)
    phone_price.append(i.text) 
    
ph_url=driver3.find_elements(By.XPATH,'//img[@class="_396cs4 _3exPp9"]')
for i in ph_url:
    phone_link.append(i.get_attribute('src'))
    #print(i.get_attribute('src'))
#print(brand_name)
#print(smartphone_name)
#print(phone_ram)
#print(phone_storage)
#print(display_size)
#print(primary_camara)
#print(secondary_camara)
#print(battery_capacity)
#print(phone_price)

# %%
mobile_data=list(zip(brand_name,smartphone_name,phone_ram,phone_storage,display_size,primary_camara,secondary_camara,battery_capacity,phone_price))
mobile_df=pd.DataFrame(mobile_data,columns=["Brand","Mobile","RAM","ROM","Display","Primary Camara","Front Camara","Battery","Price"])
mobile_df
#print(phone_link)
# Out:
#       Brand                                      Mobile        RAM  \
# 0   SAMSUNG          Galaxy F13 (Waterfall Blue, 64 GB)  4 GB RAM
# 1   SAMSUNG          Galaxy F13 (Sunrise Copper, 64 GB)  4 GB RAM
# 2   SAMSUNG          Galaxy F13 (Nightsky Green, 64 GB)  4 GB RAM
# 3   SAMSUNG            Galaxy S21 FE 5G (Olive, 128 GB)  8 GB RAM
# 4   SAMSUNG           Galaxy F23 5G (Aqua Blue, 128 GB)  6 GB RAM
# 5   SAMSUNG        Galaxy F23 5G (Forest Green, 128 GB)  6 GB RAM
# 6   SAMSUNG        Galaxy F23 5G (Copper Blush, 128 GB)  6 GB RAM
# 7   SAMSUNG         Galaxy S21 FE 5G (Graphite, 128 GB)  8 GB RAM
# 8   SAMSUNG         Galaxy F13 (Waterfall Blue, 128 GB)  4 GB RAM
# 9   SAMSUNG        Galaxy F23 5G (Forest Green, 128 GB)  4 GB RAM
# 10  SAMSUNG         Galaxy F13 (Sunrise Copper, 128 GB)  4 GB RAM
# 11  SAMSUNG         Galaxy F13 (Nightsky Green, 128 GB)  4 GB RAM
# 12  SAMSUNG           Galaxy F23 5G (Aqua Blue, 128 GB)  4 GB RAM
# ...

# %%
#Q-5
driver5=webdriver.Chrome(r"D:\Software\chromedriver_win32\chromedriver.exe")
driver5.get("https://www.google.com/maps")

# %%
search_city=driver5.find_element(By.CLASS_NAME,"tactile-searchbox-input")
search_city.send_keys('vapi')
search_map=driver5.find_element(By.CLASS_NAME,"mL3xi")
search_map.click()

# %%
source= driver5.find_element(By.XPATH,"MyME0d widget-scene-canvas");
action = ActionChains(driver5)
action.context_click(source).perform()

# %%
#Q-6
driver6=webdriver.Chrome(r"D:\Software\chromedriver_win32\chromedriver.exe")
driver6.get("https://trak.in/india-startup-funding-investment-2015/")

# %%
date=[]
startup_name=[]
industry=[]
sub_vertical=[]
location=[]
investor_name=[]
investment_type=[]
amount=[]

dd=driver6.find_elements(By.XPATH,'//td[@class="column-2"]')
for i in dd[5:29]:
    #print(i.text)
    date.append(i.text)
    
startup=driver6.find_elements(By.XPATH,'//td[@class="column-3"]')
for i in startup[5:29]:
    #print(i.text)
    startup_name.append(i.text)
    
indu=driver6.find_elements(By.XPATH,'//td[@class="column-4"]')
for i in indu[5:29]:
    #print(i.text)
    industry.append(i.text)
    
vertical=driver6.find_elements(By.XPATH,'//td[@class="column-5"]')
for i in vertical[5:29]:
    #print(i.text)
    sub_vertical.append(i.text)

loc=driver6.find_elements(By.XPATH,'//td[@class="column-6"]')
for i in loc[5:29]:
    #print(i.text)
    location.append(i.text)
    
invest_name=driver6.find_elements(By.XPATH,'//td[@class="column-7"]')
for i in invest_name[5:29]:
    #print(i.text)
    investor_name.append(i.text)
    
invest_type=driver6.find_elements(By.XPATH,'//td[@class="column-8"]')
for i in invest_type[5:29]:
    #print(i.text)
    investment_type.append(i.text)
    
invest_money=driver6.find_elements(By.XPATH,'//td[@class="column-9"]')
for i in invest_money[5:29]:
    #print(i.text)
    amount.append(i.text)

startup_data=list(zip(date,startup_name,industry,sub_vertical,location,investor_name,investment_type,amount))
startup_df=pd.DataFrame(startup_data,columns=["Date","Startup Name","Industry/Vertical","Sub-Vertical","City/Location","Investor's Name","Investment Type","Amount"])
print(startup_df)
# Out:
#           Date            Startup Name       Industry/Vertical  \
# 0   04/03/2021               DealShare              E-commerce
# 1   23/03/2021             SkilloVilla                Edu-tech
# 2   25/03/2021                CityMall              E-commerce
# 3   26/03/2021                   DotPe                 FinTech
# 4   30/03/2021                   Dunzo              E-commerce
# 5   30/03/2021                  BYJU’S                Edu-tech
# 6   31/03/2021                Uniphore              Technology
# 7   11/02/2021                Doubtnut                Edu Tech
# 8   22/02/2021                  Zomato             Hospitality
# 9   19/02/2021               Fingerlix             Hospitality
# 10  17/02/2021                   Zolve                 FinTech
# 11  15/02/2021               KreditBee                 Finance
# 12  12/02/2021               Pepperfry              E-commerce
# 13  12/02/2021                 Grofers              E-Commerce
# ...

# %%
#Q-7
driver7=webdriver.Chrome(r"D:\Software\chromedriver_win32\chromedriver.exe")
driver7.get("https://www.digit.in/search/?keyword=gaming%20laptop")

# %%
#top=driver7.find_element(By.XPATH,"/html/body/div[6]/div[2]/div[1]/div/form/ul/li[5]/label/input")
#top.click()

# %%
laptop_name=[]
laptop_link=[]

laptop=driver7.find_elements(By.XPATH,'//div[@class="searchProduct-desc"]')
for i in laptop:
    print(i.text)
    laptop_name.append(i.text)

lap_link=driver7.find_elements(By.CLASS_NAME,"lzy_img")
for i in lap_link:
    print(i.get_attribute('src'))
    laptop_link.append(i.get_attribute('src'))
# Out:
# ASUS TUF Gaming Laptop FX506LI-HN270T
# Asus G750JX-CV069P
# Dell G15 Gaming Ryzen 5 6-core-5600H (2021)
# Alienware M14x
# Acer Predator Triton 700
# Dell G15 Gaming Ryzen5-5600H 8GB (2022)
# ASUS TUF Gaming FX505DD-AL185T
# HP Pavilion Gaming 15 Core i5
# Asus TUF Gaming A15
# HP Envy 15-k006tx
# https://static.digit.in/product/thumb_224010_product_td_300.jpeg
# https://static.digit.in/product/thumb_27856_product_td_300.jpeg
# https://static.digit.in/product/thumb_206681_product_td_300.jpeg
# ...:image/png;base64,R0lGODlhAQABAAD/ACwAAAAAAQABAAACADs=
# ...:image/png;base64,R0lGODlhAQABAAD/ACwAAAAAAQABAAACADs=
# ...:image/png;base64,R0lGODlhAQABAAD/ACwAAAAAAQABAAACADs=
# ...://www.digit.in/images/hot_deals_image.jpg
# https://www.digit.in/images/powerd_amazon_image.jpg

# %%
#Q-8

driver8=webdriver.Chrome(r"D:\Software\chromedriver_win32\chromedriver.exe")
driver8.get("https://www.forbes.com/billionaires/")

# %%
top_rank=[]
person_name=[]
net_wort=[]
person_age=[]
person_citizenship=[]
companay_source=[]
person_industary=[]

rank=driver8.find_elements(By.XPATH,'//div[@class="rank"]')
for i in rank[0:100]:
    #print(i.text)
    top_rank.append(i.text)
    
name=driver8.find_elements(By.XPATH,'//div[@class="personName"]')
for i in name[0:100]:
    #print(i.text)
    person_name.append(i.text) 
    
income=driver8.find_elements(By.XPATH,'//div[@class="netWorth"]')
for i in income[0:100]:
    #print(i.text)
    net_wort.append(i.text)
    
p_age=driver8.find_elements(By.XPATH,'//div[@class="age"]')
for i in p_age[0:100]:
    #print(i.text)
    person_age.append(i.text)
    
city=driver8.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
for i in city[0:100]:
    #print(i.text)
    person_citizenship.append(i.text) 
    
source=driver8.find_elements(By.XPATH,'//span[@class="source-text"]')
for i in source[0:100]:
    #print(i.text)
    companay_source.append(i.text) 

indu=driver8.find_elements(By.XPATH,'//div[@class="category"]')
for i in indu[0:100]:
    #print(i.text)
    person_industary.append(i.text) 

print(len(person_industary))
# Out:
# 100

# %%
billionaire_data=list(zip(top_rank,person_name,net_wort,person_age,person_citizenship,companay_source,person_industary))
billionaire_df=pd.DataFrame(billionaire_data,columns=["Rank","Name","Networth","Sub-Age","Citizenship","Source","Industry"])
print(billionaire_df)
# Out:
#     Rank                      Name Networth Sub-Age    Citizenship  \
# 0     1.                 Elon Musk   $219 B      50  United States
# 1     2.                Jeff Bezos   $171 B      58  United States
# 2     3.  Bernard Arnault & family   $158 B      73         France
# 3     4.                Bill Gates   $129 B      66  United States
# 4     5.            Warren Buffett   $118 B      91  United States
# ..   ...                       ...      ...     ...            ...
# 95   96.               Steve Cohen  $17.4 B      65  United States
# 96   97.          Vladimir Potanin  $17.3 B      61         Russia
# 97   98.      Harold Hamm & family  $17.2 B      76  United States
# 98   99.              Sun Piaoyang  $17.1 B      63          China
# 99  100.        Luo Liguo & family    $17 B      66          China
#
#                 Source               Industry
# 0        Tesla, SpaceX             Automotive
# 1               Amazon             Technology
# ...

# %%
#Q-9

driver9=webdriver.Chrome(r"D:\Software\chromedriver_win32\chromedriver.exe")
driver9.get("https://www.youtube.com/watch?v=-pzwRwYlXMw&list=PL6n9fhu94yhVm6S8I2xd6nYz2ZORd7X2v")

# %%
comment_name=[]
comment_content=[]


com_name=driver9.find_elements(By.ID,'author-text')
 
for i in com_name:
    print(i.text)
    comment_name.append(i.text)
# Out:
# Duval Thomas
# Swathi Reddy
# TheOld Crab
# Mahdi tahsildari
# Jitendra Sabat
# Umesh Kumar
# Vimal
# nevine shafik
#
# physman laser
# ravi teja
# Sony M
# MrKishoreS
# Tudor Costache
# Ram Pravesh
# Jehangir Wahid Shah
# Memories of Bharathi
# Shashank Kuchibhotla
# Nihar Nanda
# Kaushik Poojari

# %%
content=driver9.find_elements(By.ID,'content-text')
 
for i in content:
    print(i.text)
    comment_content.append(i.text)
# Out:
# As an old  former C programmer returning to the development world, these tutorials are a welcome change to the run of the mill tutorials. The whole series is packed with relevant, re-producible examples that are clearly explained and support the learning process.  Thank You, Thank You, Thank You, Venkat!!!!   I cant wait for the Books!!!!
# Hi Mr. Venkat, I have been following your tutorials for SQL Server, ASP.NET and ASP.NET MVC.  Making a video tutorial such interesting is nothing but extraordinary. You are an expert at making even the most complicated subject sound very simple.Your videos are helping me a lot. Thanks a lot.
# ...

# %%
print(len(comment_name))
print(len(comment_content))
# Out:
# 20
# 20

# %%
#Q-10

driver10=webdriver.Chrome(r"D:\Software\chromedriver_win32\chromedriver.exe")
driver10.get("https://www.hostelworld.com/")

# %%
place_search=driver10.find_element(By.CLASS_NAME,"location-text")
place_search.send_keys('London')

# %%
place_search=driver10.find_element(By.CLASS_NAME,"search-input")
place_search.send_keys('London')

# %%
select=driver10.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[1]/div/div/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]")
select.click()

# %%
go=driver10.find_element(By.CLASS_NAME,"button")
go.click()

# %%
hostel_name=[]
total_distance=[]
hostel_ratings=[]
hostel_reviews=[]
overall_review=[]
private_price=[]
dorm_price=[]
facility_description=[]

name=driver10.find_elements(By.XPATH,'//h2[@class="title title-6"]')
for i in name:
    #print(i.text)
    hostel_name.append(i.text)
    
distance=driver10.find_elements(By.XPATH,'//span[@class="description"]')
for i in distance:
    #print(i.text)
    total_distance.append(i.text) 
    
rating=driver10.find_elements(By.XPATH,'//div[@class="score orange big"]')
for i in rating:
    #print(i.text)
    hostel_ratings.append(i.text)
    
tot_review=driver10.find_elements(By.XPATH,'//div[@class="reviews"]')
for i in tot_review:
    #print(i.text)
    hostel_reviews.append(i.text)
    
over_review=driver10.find_elements(By.XPATH,'//div[@class="keyword"]')
for i in over_review:
    #print(i.text)
    overall_review.append(i.text)
        
private=driver10.find_elements(By.XPATH,'//div[@class="price title-5"]')
for i in private:
    #print(i.text)
    dorm_price.append(i.text)

facility=driver10.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')
for i in facility:
    #print(i.text)
    facility_description.append(i.text)

print(len(hostel_name),len(total_distance),len(hostel_ratings),len(hostel_reviews),len(overall_review),len(dorm_price),len(facility_description))
# Out:
# 16 16 13 16 18 18 16
